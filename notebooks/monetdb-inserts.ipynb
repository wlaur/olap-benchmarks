# %%
# ruff: noqa: F401

# %%
# %load_ext autoreload
# %load_ext pyinstrument

# %autoreload 2

# %%
import sys

sys.path.insert(0, "..")

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from datetime import datetime, timedelta
from pathlib import Path

import hvplot.polars
import numpy as np
import polars as pl
from sqlalchemy import text
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='bfde37ed-f261-49c2-b045-eb710a8d53e2'>
#   <div id="ed41b374-20a0-48bc-8a11-9abb5e248b01" data-root-id="bfde37ed-f261-49c2-b045-eb710a8d53e2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from olap_benchmarks.settings import setup_stdout_logging

setup_stdout_logging()

# %%
N = 1_000

cols = ",\n\t".join(f"cast({n * 1000}.0 * rand() / 2147483648.0 as real) as c{n}" for n in range(1, N))

generate_statement = f"""
with time_index as (
select
	*
from
	generate_series(cast('2025-01-01' as timestamp),
     cast('2027-01-01' as timestamp),
     interval '1' minute)
),
dataset as(
select
	value as time,
	{cols}
from
	time_index
)
select
	*
from
	dataset
"""

create_table_statement = f"""
create table data as {generate_statement};

alter table data add constraint primary key (time);
"""

print(generate_statement)
# Out:
# with time_index as (
# select
# 	*
# from
# 	generate_series(cast('2025-01-01' as timestamp),
#      cast('2027-01-01' as timestamp),
#      interval '1' minute)
# ),
# dataset as(
# select
# 	value as time,
# 	cast(1000.0 * rand() / 2147483648.0 as real) as c1,
# 	cast(2000.0 * rand() / 2147483648.0 as real) as c2,
# 	cast(3000.0 * rand() / 2147483648.0 as real) as c3,
# 	cast(4000.0 * rand() / 2147483648.0 as real) as c4,
# 	cast(5000.0 * rand() / 2147483648.0 as real) as c5,
# 	cast(6000.0 * rand() / 2147483648.0 as real) as c6,
# 	cast(7000.0 * rand() / 2147483648.0 as real) as c7,
# 	cast(8000.0 * rand() / 2147483648.0 as real) as c8,
# 	cast(9000.0 * rand() / 2147483648.0 as real) as c9,
# 	cast(10000.0 * rand() / 2147483648.0 as real) as c10,
# 	cast(11000.0 * rand() / 2147483648.0 as real) as c11,
# 	cast(12000.0 * rand() / 2147483648.0 as real) as c12,
# 	cast(13000.0 * rand() / 2147483648.0 as real) as c13,
# 	cast(14000.0 * rand() / 2147483648.0 as real) as c14,
# ...

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import Session

e = create_engine("monetdb://monetdb:monetdb@localhost/benchmark")

with Session(e) as s:
    ret = s.execute(text("select 1")).fetchall()
    print(ret)
# Out:
# /Users/williamlauren/repos/olap-benchmarks/.venv/lib/python3.13/site-packages/sqlalchemy_monetdb/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 12:34:11.001 33548 INFO pymonetdb.mapi MainThread : Established connection to monetdb://localhost/benchmark
# [(1,)]
